# %% [markdown]
# <a href="https://colab.research.google.com/github/Deviapritha/Part-Assignments/blob/main/Copy_of_Python_Assignment_1_Data_Structures_Strings_%26_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your Name: ")

string1 = "Hello "
result = string1 + name
print(result)
# Out:
# Enter your Name: Devi
# Hello Devi

# %%
string3 = ", welcome to Python programming"
result = result + string3

print(result)
# Out:
# Hello Devi, welcome to Python programming

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("a. First character:", text[0])
# Out:
# Enter your Name: devi
# a. First character: H

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("b. Last character:", text[-1])
# Out:
# Enter your Name: Devi
# b. Last character: g

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("c. First 5 characters:", text[:5])
# Out:
# Enter your Name: Devi
# c. First 5 characters: Hello

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("d. Last 11 characters:", text[-11:])
# Out:
# Enter your Name: devi
# d. Last 11 characters: programming

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("e. Reverse:", text[::-1])
# Out:
# Enter your Name: devi
# e. Reverse: gnimmargorp nohtyP ot emoclew ,ived olleH

# %%
name = input("Enter your Name: ")

text = "Hello " + name + ", welcome to Python programming"
print("f. Python:", text[text.index("Python"):text.index("Python") + 6])
# Out:
# Enter your Name: devi
# f. Python: Python

# %%
## String Methods
strM = "Python beginner tutorial"
print(strM[0])
print(strM[-1])
print(strM[:6])
print(strM[::-1])
# Out:
# P
# l
# Python
# lairotut rennigeb nohtyP

# %%
strM = "Python beginner tutorial"
print("a. Uppercase:", strM.upper())
print("b. Lowercase:", strM.lower())
print("c. Capitalize:", strM.capitalize())
print("d. Number of 't':", strM.count("t"))
print("e. Replaced string:", strM.replace("Python", "Data Analytics"))
# Out:
# a. Uppercase: PYTHON BEGINNER TUTORIAL
# b. Lowercase: python beginner tutorial
# c. Capitalize: Python beginner tutorial
# d. Number of 't': 3
# e. Replaced string: Data Analytics beginner tutorial

# %%
##Tuples (Creation, Modification and Access) :

tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)
t_combine = tuple1 + tuple2
print("a. Combined tuple:", t_combine)
print("b. Repeated 3 times:", t_combine * 3)
print("c. 3rd element:", t_combine[2])
print("d. First three elements:", t_combine[:3])
print("e. Last three elements:", t_combine[-3:])
# Out:
# a. Combined tuple: (10, 20, 30, 40, 50, 60)
# b. Repeated 3 times: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# c. 3rd element: 30
# d. First three elements: (10, 20, 30)
# e. Last three elements: (40, 50, 60)
